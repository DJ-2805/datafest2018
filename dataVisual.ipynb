# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('Datafest/data5k.csv')
points = pd.DataFrame(data)

# %%
points
#points['jobAgeDays'].describe()
#points['jobLanguage'].describe()
#points['experienceRequired'].describe()
#points['jobAgeDays'].describe()
# Out:
#             companyId       jobId        date country stateProvince  \
# 0       company103336  job0343064  2017-02-21      US            MI
# 1        company38334  job0082493  2016-11-02      US            PA
# 2        company38334  job0082493  2016-11-03      US            PA
# 3        company38334  job0082493  2016-11-04      US            PA
# 4        company38334  job0082493  2016-11-05      US            PA
# 5        company38334  job0082493  2016-11-06      US            PA
# 6        company38334  job0082493  2016-11-07      US            PA
# 7        company38334  job0082493  2016-11-08      US            PA
# 8        company38334  job0082493  2016-11-09      US            PA
# 9        company38334  job0082493  2016-11-10      US            PA
# 10       company38334  job0082493  2016-11-11      US            PA
# 11       company38334  job0082493  2016-11-12      US            PA
# 12       company38334  job0082493  2016-11-13      US            PA
# ...

# %%
current_palette = sns.color_palette()
corr=points.corr()

plt.figure(figsize=(15, 15))

sns.heatmap(corr, vmax=.8, linewidths=0.01, square=True,annot=True,cmap='YlGnBu',linecolor="white")
plt.title('Correlation between features');

# %%
points['jobAgeDays'].plot(kind='hist', bins=500)

# %%
points['jobLanguage'].value_counts().plot('bar')

# %%
points['experienceRequired'].value_counts().plot('bar')

# %%
points['educationRequirement'].value_counts().plot('bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'educationRequirement'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-f3b856dd5ac5> in <module>()
# ...
